# %% [markdown]
# # Assignment 7 — NumPy, Pandas & Matplotlib Basics
#
# **Deadline:** 26.01.26
# Структура: `Assignment-7/Notebooks/`
#
# > Запускай ячейки по порядку (Shift+Enter).
#
#
# ## Part 1: NumPy (Numerical Computing)

# %%
# !pip install numpy pandas matplotlib

# %%
import numpy as np

# %% [markdown]
# ## Task 1: Create Arrays
#
# ### 1) 1D array from 1 to 10

# %%
arr1 = np.arange(1, 11)
arr1

# %% [markdown]
# ### 2) 2D array (3×3) with random integers

# %%
arr2 = np.random.randint(1, 100, size=(3, 3))
arr2

# %% [markdown]
# ## Task 2: Array Operations
#
# Работаем с `arr1`.

# %% [markdown]
# ### 1) Sum, mean, max

# %%
arr_sum = arr1.sum()
arr_mean = arr1.mean()
arr_max = arr1.max()
(arr_sum, arr_mean, arr_max)

# %% [markdown]
# ### 2) Multiply all elements by 2

# %%
arr_times2 = arr1 * 2
arr_times2

# %% [markdown]
# ### 3) Replace all values > 5 with 0

# %%
arr_replaced = arr1.copy()
arr_replaced[arr_replaced > 5] = 0
arr_replaced
