# %% [markdown]
# # Assignment 7 — NumPy, Pandas & Matplotlib Basics
#
# **Deadline:** 26.01.26
# Структура: `Assignment-7/Notebooks/`
#
# > Запускай ячейки по порядку (Shift+Enter).
#
#
# ## Part 2: Pandas (Data Analysis)

# %%
# !pip install numpy pandas matplotlib

# %%
import pandas as pd

# %% [markdown]
# ## Task 3: Create a DataFrame
#
# Создай DataFrame с колонками **Name, Age, Score** и минимум 5 студентов.

# %%
data = {
    "Name": ["Aruzhan", "Dias", "Batyr", "Amina", "Nursultan"],
    "Age":  [19, 21, 20, 22, 18],
    "Score":[78, 88, 95, 81, 67]
}

df = pd.DataFrame(data)
df

# %% [markdown]
# ## Task 4: Data Exploration

# %% [markdown]
# ### 1) Display the first 3 rows

# %%
df.head(3)

# %% [markdown]
# ### 2) Summary statistics using describe()

# %%
df.describe()

# %% [markdown]
# ### 3) Find the average score

# %%
avg_score = df["Score"].mean()
avg_score

# %% [markdown]
# ## Task 5: Data Filtering

# %% [markdown]
# ### 1) Select students older than 20

# %%
df[df["Age"] > 20]

# %% [markdown]
# ### 2) Select students with a score above 80

# %%
df[df["Score"] > 80]
